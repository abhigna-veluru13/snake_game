# %%
import turtle
import time
import random

# Set up the screen
win = turtle.Screen()
win.title("Snake Game")
win.bgcolor("black")
win.setup(width=600, height=600)
win.tracer(0)  # Turns off the screen updates

# Snake segments
segments = []

# Create the head of the snake
head = turtle.Turtle()
head.shape("square")
head.color("white")
head.penup()
head.goto(0, 0)
head.direction = "stop"
segments.append(head)

# Create the food
food = turtle.Turtle()
food.speed(0)
food.shape("circle")
food.color("red")
food.penup()
food.goto(0, 100)

# Functions to control the snake
def go_up():
    if head.direction != "down":
        head.direction = "up"

def go_down():
    if head.direction != "up":
        head.direction = "down"

def go_left():
    if head.direction != "right":
        head.direction = "left"

def go_right():
    if head.direction != "left":
        head.direction = "right"

def move():
    if head.direction == "up":
        y = head.ycor()
        head.sety(y + 20)
    if head.direction == "down":
        y = head.ycor()
        head.sety(y - 20)
    if head.direction == "left":
        x = head.xcor()
        head.setx(x - 20)
    if head.direction == "right":
        x = head.xcor()
        head.setx(x + 20)

# Keyboard bindings
win.listen()
win.onkey(go_up, "Up")
win.onkey(go_down, "Down")
win.onkey(go_left, "Left")
win.onkey(go_right, "Right")

# Main game loop
while True:
    win.update()

    # Check for a collision with the food
    if head.distance(food) < 20:
        # Move the food to a random spot
        x = random.randint(-290, 290)
        y = random.randint(-290, 290)
        food.goto(x, y)

        # Add a segment to the snake
        new_segment = turtle.Turtle()
        new_segment.speed(0)
        new_segment.shape("square")
        new_segment.color("grey")
        new_segment.penup()
        segments.append(new_segment)

    # Move the end segments first in reverse order
    for index in range(len(segments) - 1, 0, -1):
        x = segments[index - 1].xcor()
        y = segments[index - 1].ycor()
        segments[index].goto(x, y)

    # Move segment 0 to where the head is
    if len(segments) > 0:
        x = head.xcor()
        y = head.ycor()
        segments[0].goto(x, y)

    move()

    # Check for a collision with the wall
    if head.xcor() > 290 or head.xcor() < -290 or head.ycor() > 290 or head.ycor() < -290:
        time.sleep(1)
        head.goto(0, 0)
        head.direction = "stop"

        # Hide the segments
        for segment in segments:
            segment.goto(1000, 1000)  # Hide segment off-screen

        # Clear the segment list
        segments.clear()

    # Check for head collision with body segments
    for segment in segments:
        if segment.distance(head) < 20:
            time.sleep(1)
            head.goto(0, 0)
            head.direction = "stop"

            # Hide the segments
            for segment in segments:
                segment.goto(1000, 1000)

            # Clear the segment list
            segments.clear()

    time.sleep(0.1)

win.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[2], line 101
#      98     y = head.ycor()
#      99     segments[0].goto(x, y)
# --> 101 move()
#     103 # Check for a collision with the wall
#     104 if head.xcor() > 290 or head.xcor() < -290 or head.ycor() > 290 or head.ycor() < -290:
#
# Cell In[2], line 52, in move()
#      50 if head.direction == "up":
#      51     y = head.ycor()
# ---> 52     head.sety(y + 20)
#      53 if head.direction == "down":
#      54     y = head.ycor()
#
# File c:\Users\91995\AppData\Local\Programs\Python\Python312-32\Lib\turtle.py:1825, in TNavigator.sety(self, y)
#    1809 def sety(self, y):
#    1810     """Set the turtle's second coordinate to y
#    1811
#    1812     Argument:
#    (...)
#    1823     (0.00, -10.00)
#    1824     """
# -> 1825     self._goto(Vec2D(self._position[0], y))
#
# File c:\Users\91995\AppData\Local\Programs\Python\Python312-32\Lib\turtle.py:3230, in RawTurtle._goto(self, end)
#    3222 go_modes = ( self._drawing,
#    3223              self._pencolor,
#    3224              self._pensize,
#    3225              isinstance(self._fillpath, list))
#    3226 screen = self.screen
#    3227 undo_entry = ("go", self._position, end, go_modes,
#    3228               (self.currentLineItem,
#    3229               self.currentLine[:],
# -> 3230               screen._pointlist(self.currentLineItem),
#    3231               self.items[:])
#    3232               )
#    3233 if self.undobuffer:
#    3234     self.undobuffer.push(undo_entry)
#
# File c:\Users\91995\AppData\Local\Programs\Python\Python312-32\Lib\turtle.py:745, in TurtleScreenBase._pointlist(self, item)
#     737 def _pointlist(self, item):
#     738     """returns list of coordinate-pairs of points of item
#     739     Example (for insiders):
#     740     >>> from turtle import *
#    (...)
#     743     (9.9999999999999982, 0.0)]
#     744     >>> """
# --> 745     cl = self.cv.coords(item)
#     746     pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#     747     return  pl
#
# File <string>:1, in coords(self, *args, **kw)
#
# File c:\Users\91995\AppData\Local\Programs\Python\Python312-32\Lib\tkinter\__init__.py:2840, in Canvas.coords(self, *args)
#    2836 """Return a list of coordinates for the item given in ARGS."""
#    2837 args = _flatten(args)
#    2838 return [self.tk.getdouble(x) for x in
#    2839                    self.tk.splitlist(
# -> 2840            self.tk.call((self._w, 'coords') + args))]
#
# TclError: invalid command name ".!canvas"
